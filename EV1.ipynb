# %% [markdown]
# <a href="https://colab.research.google.com/github/EdwardMatsuzaka/Evidencia1/blob/main/EV1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime 

ejemplares={}

while True: 
  opcion=int(input("*MENÚ PRINCIPAL*\nIngrese un numero de opcion a ejecutar:\n=Opción 1: Registrar un nuevo ejemplar\n=Opción 2: Consultas y reportes de un ejemplar\n=Opción 3: Salir del Programa\n> "))
  if opcion > 3 or opcion < 1:
    print("La opción no es compatible, intente de nuevo")
    continue
  if opcion == 1:
    titulo=input("Ingrese el titulo del nuevo ejemplar:\n> ").upper()

    autor=input(f"Ingrese el nombre del autor del ejemplar {titulo}:\n> ").upper()

    genero=input(f"Ingrese el tipo de género que tiene el ejemplar:\n> ").upper()

    año_publicacion=input(f"Ingrese el año de publicación del ejemplar:\n> ")
    año=datetime.datetime.strptime(año_publicacion, '%Y').date()

    isbn=input("Ingrese el ISBN del ejemplar:\n> ").upper()

    fecha_adquisicion=input("Ingrese la fecha de adquisición del ejemplar con el siguiente formato(dd/mm/aaaa):\n> ")
    fecha=datetime.datetime.strptime(fecha_adquisicion, '%d/%m/%Y').date()

    clave=max(ejemplares, default=0)+1
    ejemplares[clave]=[titulo, autor, genero, año,isbn, fecha]


  if opcion == 2:
    while True:
      consultas_reportes=int(input("*MENÚ DE CONSULTAS Y REPORTES*\nSeleccione una de las siguientes opciónes que desee ejecutar:\n=Opción 1: Consultar titulo\n=Opción 2: Reporte\n=Opción 3: Volver al Menú Principal\n> "))
      if consultas_reportes == 1:

          consultas_titulo=int(input("Consultas de Titulo:\n-Opción 1: Consultar por medio de título:\n-Opción 2: Volver al Menú de Consultas y Reportes\n> "))
          if consultas_titulo == 1:
            lista_titulo=[titulo for titulo, autor, genero, año, isbn, fecha in ejemplares.values()]
            print(f"Titulos de ejemplares existentes:")
            print(f"{lista_titulo}")
            consulta_reporte=input("Ingrese el titulo que desee consultar para mostrar sus datos:\n> ").upper()
            for titulo, autor, genero, año, isbn, fecha in ejemplares.values():
              if titulo == consulta_reporte:
                print(f"=Titulo: {titulo}\n=Autor: {autor}\n=Genero: {genero}\n=Año de Publicación: {año}\n=ISBN: {isbn}\n=Fecha: {fecha}")
          if consultas_titulo == 2:
            break
      if consultas_reportes == 2:
        while True:
          reportes=int(input("**MENÚ DE REPORTES**\nSeleccione el tipo de Reporte que desee:\n=Opción 1: Catálogo completo\n=Opción 2: Reporte por Autor\n=Opción 3: Reporte por Género\n=Opción 4: Reporte por Publicación de Año\n=Opción 5: Volver al Menú de Consultas y Reportes\n>"))
          if reportes == 1:
            print(f"="* 30)
            print("**EJEMPLARES**")
            print(f"="* 30)
            for titulo, autor, genero, año, isbn, fecha in ejemplares.values():
              print(f"=Titulo: {titulo}\n=Autor: {autor}\n=Genero: {genero}\n=Año de Publicación: {año}\n=ISBN: {isbn}\n=Fecha: {fecha}")
              print(f"="* 30)
          if reportes == 2:
            lista_autores=[autor for titulo, autor, genero, año, isbn, fecha in ejemplares.values()]
            autores_unicos=set(lista_autores)
            print(f"Autores de ejemplares existentes:")
            print(f"{autores_unicos}")
            consulta_reporte=input("Ingrese el autor que desee consultar para mostrar sus datos:\n> ").upper()
            print(f"="*30)
            print(f"Ejemplares del autor {consulta_reporte}")
            print(f"="*30)
            for titulo, autor, genero, año, isbn, fecha in ejemplares.values():
              if autor == consulta_reporte:
                print(f"=Titulo: {titulo}\n=Autor: {autor}\n=Genero: {genero}\n=Año de Publicación: {año}\n=ISBN: {isbn}\n=Fecha: {fecha}")
                print(f"-"*30)  
          if reportes == 3:
            lista_generos=[genero for titulo, autor, genero, año, isbn, fecha in ejemplares.values()]
            generos_unicos=set(lista_generos)
            print(f"Géneros de ejemplares existentes:")
            print(f"{generos_unicos}")
            consulta_reporte=input("Ingrese el género que desee consultar para mostrar sus datos:\n> ").upper()
            print(f"="*30)
            print(f"Ejemplares del género {consulta_reporte}")
            print(f"="*30)
            for titulo, autor, genero, año, isbn, fecha in ejemplares.values():
              if genero == consulta_reporte:
                print(f"=Titulo: {titulo}\n=Autor: {autor}\n=Genero: {genero}\n=Año de Publicación: {año}\n=ISBN: {isbn}\n=Fecha: {fecha}")
                print(f"-"*30) 
          if reportes == 4:
            lista_años=[año for titulo, autor, genero, año, isbn, fecha in ejemplares.values()]
            años_unicos=set(lista_años)
            print(f"Años de publicación de ejemplares existentes:")
            print(f"{años_unicos}")
            consulta_reporte=input("Ingrese el año de publicación que desee consultar para mostrar sus datos:\n> ").upper()
            print(f"="*40)
            print(f"Ejemplares del año de publicación {consulta_reporte}")
            print(f"="*40)
            for titulo, autor, genero, año, isbn, fecha in ejemplares.values():
              if año == consulta_reporte:
                print(f"=Titulo: {titulo}\n=Autor: {autor}\n=Genero: {genero}\n=Año de Publicación: {año}\n=ISBN: {isbn}\n=Fecha: {fecha}")
                print(f"-"*30) 
          if reportes == 5:
            break
      
      if consultas_reportes == 3:
        break
  if opcion == 3:
    print("---Programa Finalizado, que tenga un lindo día---")
    break

# %%
import datetime 

ejemplares=ejemplares={1:["MOON","DEHYA","CIENCIA","2021","1029374","20/08/2021"], 2:["LAS DOCE LUNAS","DEHYA","FICCION","2010","0183664","08/12/2010"], 3:["POR EL AIRE","ROBLEIS","FICCION","2021","1030385","02/02/2021"]}

while True: 
  opcion=int(input("*MENÚ PRINCIPAL*\nIngrese un numero de opcion a ejecutar:\n=Opción 1: Registrar un nuevo ejemplar\n=Opción 2: Consultas y reportes de un ejemplar\n=Opción 3: Salir del Programa\n> "))
  if opcion > 3 or opcion < 1:
    print("La opción no es compatible, intente de nuevo")
    continue
  if opcion == 1:
    titulo=input("Ingrese el titulo del nuevo ejemplar:\n> ").upper()

    autor=input(f"Ingrese el nombre del autor del ejemplar {titulo}:\n> ").upper()

    genero=input(f"Ingrese el tipo de género que tiene el ejemplar:\n> ").upper()

    año_publicacion=input(f"Ingrese el año de publicación del ejemplar:\n> ")
    año=datetime.datetime.strptime(año_publicacion, '%Y').date()

    isbn=input("Ingrese el ISBN del ejemplar:\n> ").upper()

    fecha_adquisicion=input("Ingrese la fecha de adquisición del ejemplar con el siguiente formato(dd/mm/aaaa):\n> ")
    fecha=datetime.datetime.strptime(fecha_adquisicion, '%d/%m/%Y').date()

    clave=max(ejemplares, default=0)+1
    ejemplares[clave]=[titulo, autor, genero, año,isbn, fecha]


  if opcion == 2:
    while True:
      consultas_reportes=int(input("*MENÚ DE CONSULTAS Y REPORTES*\nSeleccione una de las siguientes opciónes que desee ejecutar:\n=Opción 1: Consultar titulo\n=Opción 2: Reporte\n=Opción 3: Volver al Menú Principal\n> "))
      if consultas_reportes == 1:

          consultas_titulo=int(input("Consultas de Titulo:\n-Opción 1: Consultar por medio de título:\n-Opción 2: Volver al Menú de Consultas y Reportes\n> "))
          if consultas_titulo == 1:
            lista_titulo=[titulo for titulo, autor, genero, año, isbn, fecha in ejemplares.values()]
            print(f"Titulos de ejemplares existentes:")
            print(f"{lista_titulo}")
            consulta_reporte=input("Ingrese el titulo que desee consultar para mostrar sus datos:\n> ").upper()
            for titulo, autor, genero, año, isbn, fecha in ejemplares.values():
              if titulo == consulta_reporte:
                print(f"=Titulo: {titulo}\n=Autor: {autor}\n=Genero: {genero}\n=Año de Publicación: {año}\n=ISBN: {isbn}\n=Fecha: {fecha}")
          if consultas_titulo == 2:
            break
      if consultas_reportes == 2:
        while True:
          reportes=int(input("**MENÚ DE REPORTES**\nSeleccione el tipo de Reporte que desee:\n=Opción 1: Catálogo completo\n=Opción 2: Reporte por Autor\n=Opción 3: Reporte por Género\n=Opción 4: Reporte por Publicación de Año\n=Opción 5: Volver al Menú de Consultas y Reportes\n>"))
          if reportes == 1:
            print(f"="* 30)
            print("**EJEMPLARES**")
            print(f"="* 30)
            for titulo, autor, genero, año, isbn, fecha in ejemplares.values():
              print(f"=Titulo: {titulo}\n=Autor: {autor}\n=Genero: {genero}\n=Año de Publicación: {año}\n=ISBN: {isbn}\n=Fecha: {fecha}")
              print(f"="* 30)
          if reportes == 2:
            lista_autores=[autor for titulo, autor, genero, año, isbn, fecha in ejemplares.values()]
            autores_unicos=set(lista_autores)
            print(f"Autores de ejemplares existentes:")
            print(f"{autores_unicos}")
            consulta_reporte=input("Ingrese el autor que desee consultar para mostrar sus datos:\n> ").upper()
            print(f"="*30)
            print(f"Ejemplares del autor {consulta_reporte}")
            print(f"="*30)
            for titulo, autor, genero, año, isbn, fecha in ejemplares.values():
              if autor == consulta_reporte:
                print(f"=Titulo: {titulo}\n=Autor: {autor}\n=Genero: {genero}\n=Año de Publicación: {año}\n=ISBN: {isbn}\n=Fecha: {fecha}")
                print(f"-"*30)  
          if reportes == 3:
            lista_generos=[genero for titulo, autor, genero, año, isbn, fecha in ejemplares.values()]
            generos_unicos=set(lista_generos)
            print(f"Géneros de ejemplares existentes:")
            print(f"{generos_unicos}")
            consulta_reporte=input("Ingrese el género que desee consultar para mostrar sus datos:\n> ").upper()
            print(f"="*30)
            print(f"Ejemplares del género {consulta_reporte}")
            print(f"="*30)
            for titulo, autor, genero, año, isbn, fecha in ejemplares.values():
              if genero == consulta_reporte:
                print(f"=Titulo: {titulo}\n=Autor: {autor}\n=Genero: {genero}\n=Año de Publicación: {año}\n=ISBN: {isbn}\n=Fecha: {fecha}")
                print(f"-"*30) 
          if reportes == 4:
            lista_años=[año for titulo, autor, genero, año, isbn, fecha in ejemplares.values()]
            años_unicos=set(lista_años)
            print(f"Años de publicación de ejemplares existentes:")
            print(f"{años_unicos}")
            consulta_reporte=input("Ingrese el año de publicación que desee consultar para mostrar sus datos:\n> ").upper()
            print(f"="*40)
            print(f"Ejemplares del año de publicación {consulta_reporte}")
            print(f"="*40)
            for titulo, autor, genero, año, isbn, fecha in ejemplares.values():
              if año == consulta_reporte:
                print(f"=Titulo: {titulo}\n=Autor: {autor}\n=Genero: {genero}\n=Año de Publicación: {año}\n=ISBN: {isbn}\n=Fecha: {fecha}")
                print(f"-"*30) 
          if reportes == 5:
            break
      
      if consultas_reportes == 3:
        break
  if opcion == 3:
    print("---Programa Finalizado, que tenga un lindo día---")
    break
# Out:
# *MENÚ PRINCIPAL*
# Ingrese un numero de opcion a ejecutar:
# =Opción 1: Registrar un nuevo ejemplar
# =Opción 2: Consultas y reportes de un ejemplar
# =Opción 3: Salir del Programa
# > 2
# *MENÚ DE CONSULTAS Y REPORTES*
# Seleccione una de las siguientes opciónes que desee ejecutar:
# =Opción 1: Consultar titulo
# =Opción 2: Reporte
# =Opción 3: Volver al Menú Principal
# > 1
# Consultas de Titulo:
# -Opción 1: Consultar por medio de título:
# -Opción 2: Volver al Menú de Consultas y Reportes
# > 1
# Titulos de ejemplares existentes:
# ['MOON', 'LAS DOCE LUNAS', 'POR EL AIRE']
# Ingrese el titulo que desee consultar para mostrar sus datos:
# > por el aire
# =Titulo: POR EL AIRE
# =Autor: ROBLEIS
# =Genero: FICCION
# =Año de Publicación: 2021
# =ISBN: 1030385
# =Fecha: 02/02/2021
# *MENÚ DE CONSULTAS Y REPORTES*
# Seleccione una de las siguientes opciónes que desee ejecutar:
# =Opción 1: Consultar titulo
# =Opción 2: Reporte
# =Opción 3: Volver al Menú Principal
# > 2
# **MENÚ DE REPORTES**
# Seleccione el tipo de Reporte que desee:
# =Opción 1: Catálogo completo
# =Opción 2: Reporte por Autor
# =Opción 3: Reporte por Género
# =Opción 4: Reporte por Publicación de Año
# =Opción 5: Volver al Menú de Consultas y Reportes
# >1
# ==============================
# **EJEMPLARES**
# ==============================
# =Titulo: MOON
# =Autor: DEHYA
# =Genero: CIENCIA
# =Año de Publicación: 2021
# =ISBN: 1029374
# =Fecha: 20/08/2021
# ==============================
# =Titulo: LAS DOCE LUNAS
# =Autor: DEHYA
# =Genero: FICCION
# =Año de Publicación: 2010
# =ISBN: 0183664
# =Fecha: 08/12/2010
# ==============================
# =Titulo: POR EL AIRE
# =Autor: ROBLEIS
# =Genero: FICCION
# =Año de Publicación: 2021
# =ISBN: 1030385
# =Fecha: 02/02/2021
# ==============================
# **MENÚ DE REPORTES**
# Seleccione el tipo de Reporte que desee:
# =Opción 1: Catálogo completo
# =Opción 2: Reporte por Autor
# =Opción 3: Reporte por Género
# =Opción 4: Reporte por Publicación de Año
# =Opción 5: Volver al Menú de Consultas y Reportes
# >2
# Autores de ejemplares existentes:
# {'ROBLEIS', 'DEHYA'}
# Ingrese el autor que desee consultar para mostrar sus datos:
# > dehya
# ==============================
# Ejemplares del autor DEHYA
# ==============================
# =Titulo: MOON
# =Autor: DEHYA
# =Genero: CIENCIA
# =Año de Publicación: 2021
# =ISBN: 1029374
# =Fecha: 20/08/2021
# ------------------------------
# =Titulo: LAS DOCE LUNAS
# =Autor: DEHYA
# =Genero: FICCION
# =Año de Publicación: 2010
# =ISBN: 0183664
# =Fecha: 08/12/2010
# ------------------------------
# **MENÚ DE REPORTES**
# Seleccione el tipo de Reporte que desee:
# =Opción 1: Catálogo completo
# =Opción 2: Reporte por Autor
# =Opción 3: Reporte por Género
# =Opción 4: Reporte por Publicación de Año
# =Opción 5: Volver al Menú de Consultas y Reportes
# >3
# Géneros de ejemplares existentes:
# {'CIENCIA', 'FICCION'}
# Ingrese el género que desee consultar para mostrar sus datos:
# > ficcion
# ==============================
# Ejemplares del género FICCION
# ==============================
# =Titulo: LAS DOCE LUNAS
# =Autor: DEHYA
# =Genero: FICCION
# =Año de Publicación: 2010
# =ISBN: 0183664
# =Fecha: 08/12/2010
# ------------------------------
# =Titulo: POR EL AIRE
# =Autor: ROBLEIS
# =Genero: FICCION
# =Año de Publicación: 2021
# =ISBN: 1030385
# =Fecha: 02/02/2021
# ------------------------------
# **MENÚ DE REPORTES**
# Seleccione el tipo de Reporte que desee:
# =Opción 1: Catálogo completo
# =Opción 2: Reporte por Autor
# =Opción 3: Reporte por Género
# =Opción 4: Reporte por Publicación de Año
# =Opción 5: Volver al Menú de Consultas y Reportes
# >4
# Años de publicación de ejemplares existentes:
# {'2010', '2021'}
# Ingrese el año de publicación que desee consultar para mostrar sus datos:
# > 2021
# ========================================
# Ejemplares del año de publicación 2021
# ========================================
# =Titulo: MOON
# =Autor: DEHYA
# =Genero: CIENCIA
# =Año de Publicación: 2021
# =ISBN: 1029374
# =Fecha: 20/08/2021
# ------------------------------
# =Titulo: POR EL AIRE
# =Autor: ROBLEIS
# =Genero: FICCION
# =Año de Publicación: 2021
# =ISBN: 1030385
# =Fecha: 02/02/2021
# ------------------------------
# **MENÚ DE REPORTES**
# Seleccione el tipo de Reporte que desee:
# =Opción 1: Catálogo completo
# =Opción 2: Reporte por Autor
# =Opción 3: Reporte por Género
# =Opción 4: Reporte por Publicación de Año
# =Opción 5: Volver al Menú de Consultas y Reportes
# >5
# *MENÚ DE CONSULTAS Y REPORTES*
# Seleccione una de las siguientes opciónes que desee ejecutar:
# =Opción 1: Consultar titulo
# =Opción 2: Reporte
# =Opción 3: Volver al Menú Principal
# > 3
# *MENÚ PRINCIPAL*
# Ingrese un numero de opcion a ejecutar:
# =Opción 1: Registrar un nuevo ejemplar
# =Opción 2: Consultas y reportes de un ejemplar
# =Opción 3: Salir del Programa
# > 3
# ---Programa Finalizado, que tenga un lindo día---
